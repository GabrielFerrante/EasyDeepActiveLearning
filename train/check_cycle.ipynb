# %% [markdown]
# ## Checando o resultado por ciclo

# %%
checkpoint = torch.load("al_checkpoints_svhn/model_cycle_3_acc_82.15.pt")
model.load_state_dict(checkpoint['model_state_dict'])
indices_utilizados = checkpoint['labeled_indices']
print(f"Este modelo foi treinado com {len(indices_utilizados)} imagens.")
